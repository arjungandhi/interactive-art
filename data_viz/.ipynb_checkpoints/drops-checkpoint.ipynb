# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import json
from drop import Drop
import random

# %%
census_data = json.load(open('censtats.json','r'))
mortality_data = json.load(open('mortality.json','r'))

# %%
zip_code = '01609' # input('enter a zipcode')
zip_data= [x for x in census_data if x['zcta'] == zip_code][0]
death_data = mortality_data[zip_data['state'][0]]

# %%
male_age_dist = { k:int(v) for k,v in zip_data['age_and_sex']['male'].items()}
female_age_dist = { k:int(v) for k,v in zip_data['age_and_sex']['female'].items()}

k_converter = {'age_0_to_9_years': 9,
 'age_10_to_19_years': 19,
 'age_20_to_29_years': 29,
 'age_30_to_39_years': 39,
 'age_40_to_49_years': 49,
 'age_50_to_59_years': 59,
 'age_60_to_69_years': 69,
 'age_70_years_and_over': 100}

total_age_dist = { k_converter[k]:v+male_age_dist[k] for k,v in female_age_dist.items()}

# %%
#create a plot and set it up to do things
fig, ax = plt.subplots(figsize=(15,15))
ax.set_facecolor('xkcd:dark grey')
sim_params = {
    'age_dist' : total_age_dist,
    'death_chance' : death_data
}
sim_length = 1000
birthrate = .3
raindrops = []
increment_rate = .05
for i in range(sim_length):
    #clearing and hiding xticks and yticks
    ax.clear()
    trash = ax.set_xticks([],minor=[])
    trash = ax.set_yticks([],minor=[])
    # possibly adding a new raindrop 
    if random.random() < birthrate:
        raindrops.append(Drop(sim_params))
    
    # looping and plotting the rain drops 
    for drop in raindrops:
        drop.loop(increment_rate)
        if drop.does_die(.05):
            del(drop)
        else:
            patch = plt.Circle((drop.x,drop.y), drop.age/100,  facecolor='xkcd:dark grey', edgecolor= 'xkcd:light grey')
            ax.add_patch(patch)
    fig.canvas.draw()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6fb578d4452e> in <module>
#      26         else:
#      27             patch = plt.Circle((drop.x,drop.y), drop.age/100,  facecolor='xkcd:dark grey', edgecolor= 'white')
# ---> 28             ax.add_patch(patch)
#      29     fig.canvas.draw()
#
# ~/.local/share/virtualenvs/interactive-art-OOr52VAb/lib/python3.9/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2031         if p.get_clip_path() is None:
#    2032             p.set_clip_path(self.patch)
# -> 2033         self._update_patch_limits(p)
#    2034         self.patches.append(p)
#    2035         p._remove_method = self.patches.remove
#
# ~/.local/share/virtualenvs/interactive-art-OOr52VAb/lib/python3.9/site-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    2059             updatex, updatey = patch.get_transform().\
#    2060                 contains_branch_seperately(self.transData)
# -> 2061             self.update_datalim(xys, updatex=updatex,
#    2062                                 updatey=updatey)
#    2063
#
# ~/.local/share/virtualenvs/interactive-art-OOr52VAb/lib/python3.9/site-packages/matplotlib/axes/_base.py in update_datalim(self, xys, updatex, updatey)
#    2140         """
#    2141         xys = np.asarray(xys)
# -> 2142         if not np.any(np.isfinite(xys)):
#    2143             return
#    2144         self.dataLim.update_from_data_xy(xys, self.ignore_existing_data_limits,
#
# <__array_function__ internals> in any(*args, **kwargs)
#
# ~/.local/share/virtualenvs/interactive-art-OOr52VAb/lib/python3.9/site-packages/numpy/core/fromnumeric.py in any(a, axis, out, keepdims, where)
#    2254
#    2255
# -> 2256 @array_function_dispatch(_any_dispatcher)
#    2257 def any(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2258     """
#
# KeyboardInterrupt:
